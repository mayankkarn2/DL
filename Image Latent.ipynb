# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

#Progress bars
from tqdm import tqdm
# tqdm.pandas()

#Paralelize pandas apply on multiple cores
#import swifter

from matplotlib import pyplot as plt
from matplotlib import style
#Nicer style
style.use('seaborn')
import seaborn as sns
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
from tensorflow import keras as k

from sklearn.model_selection import train_test_split

from gensim.models import KeyedVectors

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
df = pd.read_csv('drive/My Drive/MSIT 2nd Year/ML course/Projects/fakenews-master/data/all_data.csv')
print(df.describe())
# Out:
#          Unnamed: 0  Unnamed: 0.1  ...    second_all     third_all
# count  20015.000000   3171.000000  ...  20015.000000  20015.000000
# mean   10008.000000   2654.344056  ...     79.396203     35.265551
# std     5777.977155   1531.720152  ...     96.712714     45.056939
# min        1.000000      2.000000  ...      0.000000      0.000000
# 25%     5004.500000   1317.500000  ...     24.000000     10.000000
# 50%    10008.000000   2676.000000  ...     58.000000     25.000000
# 75%    15011.500000   3992.500000  ...    106.000000     47.000000
# max    20015.000000   5276.000000  ...   2423.000000   1264.000000
#
# [8 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'author', 'comments', 'country',
#        'crawled', 'domain_rank', 'id', 'language', 'likes', 'main_img_url',
#        'ord_in_thread', 'participants_count', 'published', 'replies_count',
#        'shares', 'site_url', 'spam_score', 'text', 'thread_title', 'title',
#        'type', 'uuid', 'caps_title', 'caps_thread', 'caps_text', 'title_len',
#        'thread_len', 'text_len', 'excl_title', 'excl_thread', 'excl_text',
#        'first_title', 'first_thread', 'first_text', 'second_title',
#        'second_thread', 'second_text', 'third_title', 'third_thread',
#        'third_text', 'anger', 'anticipation', 'disgust', 'fear', 'joy',
#        'sadness', 'surprise', 'trust', 'negative', 'positive', 'first_all',
#        'second_all', 'third_all'],
#       dtype='object')

# %%
df.main_img_url.unique()
# Out:
# array(['https://static01.nyt.com/images/2016/11/23/us/23spectacle1/23spectacle1-master768.jpg',
#        'https://static01.nyt.com/images/2016/10/18/us/18fd-trumpfoundation/18fd-trumpfoundation-master675.jpg',
#        'https://static01.nyt.com/images/2016/11/12/us/12tower1/12tower1-master768.jpg',
#        ...,
#        'http://cdns.yournewswire.com/wp-content/uploads/2016/11/trin_iraq-998x540.jpg',
#        'http://cdns.yournewswire.com/wp-content/uploads/2016/11/Aboriginal-Australian.jpg',
#        'http://cdns.yournewswire.com/wp-content/uploads/2016/11/johnsonandjohnson.jpg'],
#       dtype=object)

# %%
# !pip install Pillow

# %%
# df_image = pd.DataFrame()
l = df.main_img_url.nunique(dropna=True)
print(l)
# Out:
# 9929

# %%
# j = 0
# for _ in range(df.shape[0]):
#   print(df.iloc(i))
d= []
for i in df['main_img_url']:
  if i[8:10] != "t4":
    d.append(i)
    # j += 1
# print(j)

# %%
import urllib.request
from PIL import Image
def res(resol):
  image = Image.open(urllib.request.urlopen(resol))
  w, h = image.size
  return w, h
# print (width,height)

# %%
print(d)
# Out:
# ['https://static01.nyt.com/images/2016/11/23/us/23spectacle1/23spectacle1-master768.jpg', 'https://static01.nyt.com/images/2016/10/18/us/18fd-trumpfoundation/18fd-trumpfoundation-master675.jpg', 'https://static01.nyt.com/images/2016/11/12/us/12tower1/12tower1-master768.jpg', 'https://static01.nyt.com/images/2016/10/21/business/21VISA2sub/21VISA2sub-master768.jpg', 'https://static01.nyt.com/images/2016/11/21/us/21melania/21melania-master768.jpg', 'https://static01.nyt.com/images/2016/11/19/us/19ivanka/19ivanka-master768.jpg', 'https://static01.nyt.com/images/2016/11/17/nyregion/17TRUMPTOWER1/17TRUMPTOWER1-master768.jpg', 'https://static01.nyt.com/images/2016/10/30/nyregion/30TRUMPHEIGHTS-COMBO/30TRUMPHEIGHTS-COMBO-master768.jpg', 'https://static01.nyt.com/images/2016/11/22/business/22TRUMPUNIVERSITY/22TRUMPUNIVERSITY-master768.jpg', 'https://static01.nyt.com/images/2016/11/26/arts/26TRUMPOPERAJP/26TRUMPOPERAJP-master768.jpg', 'https://static01.nyt.com/images/2016/11/22/us/22transition
# ...

# %%
d_img = {"main_img_url":d}
df_image = pd.DataFrame(d_img)
print(df_image.head(5))
# Out:
#                                         main_img_url
# 0  https://static01.nyt.com/images/2016/11/23/us/...
# 1  https://static01.nyt.com/images/2016/10/18/us/...
# 2  https://static01.nyt.com/images/2016/11/12/us/...
# 3  https://static01.nyt.com/images/2016/10/21/bus...
# 4  https://static01.nyt.com/images/2016/11/21/us/...

# %%
# df_image.rename(columns = {0:"main_img_url"})

# %%
width = []
height = []
j = 0
for i in df_image[:10]:
  print(type(df_image[i][j]))
  r = res()
# Out:
#   File "<ipython-input-14-44a4a17e8132>", line 6
#     r = res(str(list(df_image[i]))
#                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
# %debug
